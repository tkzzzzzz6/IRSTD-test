# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# !cd /content/drive/MyDrive/Reasearch/IRSTD-test && ls
# !pip install -r requirements.txt
# !bash cm.sh
# !python train.py --model_names ACM ALCNet  --dataset_names IRSTD-1K NUAA-SIRST NUDT-SIRST
# Out:
# drive  sample_data
# cal_params.py  evaluate.py   metrics.py  README.md	   train.py
# cm.sh	       inference.py  model	 requirements.txt  utils.py
# dataset.py     loss.py	     net.py	 test.py
