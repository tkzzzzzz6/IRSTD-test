# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# !cd /content/drive/MyDrive/Reasearch/IRSTD-test && ls
# !pip install -r requirements.txt
# !bash cm.sh
# !python train.py --model_names ACM ALCNet  --dataset_names IRSTD-1K NUAA-SIRST NUDT-SIRST
# Out:
# 运行具有“BasicIRSTD (Python 3.10.19)”的单元格需要ipykernel包。
#
# 使用所需的包 <a href='command:jupyter.createPythonEnvAndSelectController'>创建 Python 环境</a>。
